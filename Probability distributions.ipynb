# %%
import numpy as np
import scipy.stats as stats

# %%
import matplotlib.pyplot as plt

# %%
proba_dist = stats.norm()

# %%
proba_dist.rvs()
# Out:
# -1.1518865527595474

# %%
proba_dist.rvs(10)
# Out:
# array([ 0.02800776, -0.13314086, -0.34620193,  1.33725833,  0.59274977,
#         0.80791537, -0.70023458, -0.96941933, -0.1282091 ,  0.08785872])

# %%
proba_dist.pdf(2)
# Out:
# 0.05399096651318806

# %%
proba_dist.cdf(2)
# Out:
# 0.9772498680518208

# %%
nrows=10
ncols=10

# %%
x, y = np.meshgrid(np.arange(nrows), np.arange(ncolumns))

# %%
x = x.ravel()
y = y.ravel()

# %%
z = proba_dist.rvs(nrows*ncolumns)

# %%
z.sort()

# %%
import seaborn as sns

# %%
sns.heatmap(np.sort(z).reshape((10,-1)), cmap="coolwarm")
plt.axis('off');

# %%
plt.scatter(np.random.random(nrows), np.random.random(ncols), c=z.reshape((10,-1)), cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/lewagon_new/lib/python3.8/site-packages/matplotlib/axes/_axes.py:4220, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4219 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4220     colors = mcolors.to_rgba_array(c)
#    4221 except (TypeError, ValueError) as err:
#
# File ~/miniconda3/envs/lewagon_new/lib/python3.8/site-packages/matplotlib/colors.py:377, in to_rgba_array(c, alpha)
#     376 else:
# --> 377     rgba = np.array([to_rgba(cc) for cc in c])
#     379 if alpha is not None:
#
# File ~/miniconda3/envs/lewagon_new/lib/python3.8/site-packages/matplotlib/colors.py:377, in <listcomp>(.0)
#     376 else:
# --> 377     rgba = np.array([to_rgba(cc) for cc in c])
#     379 if alpha is not None:
#
# ...

# %%
plt.hist(z);

# %%
plt.
