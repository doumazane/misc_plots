# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## Gaussian Model of height (4.3, p79)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/rmcelreath/rethinking/master/data/Howell1.csv', sep=';')

# %%
df
# Out:
#       height     weight   age  male
# 0    151.765  47.825606  63.0     1
# 1    139.700  36.485807  63.0     0
# 2    136.525  31.864838  65.0     0
# 3    156.845  53.041914  41.0     1
# 4    145.415  41.276872  51.0     0
# ..       ...        ...   ...   ...
# 539  145.415  31.127751  17.0     1
# 540  162.560  52.163080  31.0     1
# 541  156.210  54.062497  21.0     0
# 542   71.120   8.051258   0.0     1
# 543  158.750  52.531624  68.0     1
#
# [544 rows x 4 columns]

# %%
d.describe()

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df, x="height", y="weight")
# Out:
# <AxesSubplot:xlabel='height', ylabel='weight'>

# %%
adults = df.query("age > 17")

# %%
sns.scatterplot(data=adults, x="height", y="weight")
# Out:
# <AxesSubplot:xlabel='height', ylabel='weight'>

# %%
plt.hist(adults.height)
# Out:
# (array([ 8., 32., 62., 60., 65., 65., 35., 18.,  6.,  1.]),
#  array([136.525 , 140.7795, 145.034 , 149.2885, 153.543 , 157.7975,
#         162.052 , 166.3065, 170.561 , 174.8155, 179.07  ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(data=adults, x="height", hue='male', kde=True)
# Out:
# <AxesSubplot:xlabel='height', ylabel='Count'>

# %% [markdown]
# ## Berkson's paradox
# 6.1
# ![image.png](attachment:image.png)

# %%
N = 200
p = 0.1
nw = stats.norm().rvs(N)
tw = stats.norm().rvs(N)
s = nw + tw
q = np.quantile(s, 1-p)
selected = (s>q)

sns.scatterplot(x=tw[~selected], y=nw[~selected], label="not selected")
sns.regplot(x=tw[selected], y=nw[selected], color="red", label="selected")
plt.xlabel("trustworthiness")
plt.ylabel("newsworthiness")
plt.legend()
